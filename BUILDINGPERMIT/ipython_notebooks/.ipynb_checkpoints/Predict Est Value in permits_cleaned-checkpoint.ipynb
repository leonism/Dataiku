# %% [markdown]
# # Predicting Est Value in permits_cleaned

# %% [markdown]
# ### Notebook automatically generated from your model

# %% [markdown]
# Model Ridge (L2) regression, trained on 2020-04-21 12:52:18.

# %% [markdown]
# #### Generated on 2020-04-21 06:18:12.164135

# %% [markdown]
# prediction
# This notebook will reproduce the steps for a REGRESSION on  permits_cleaned.
# The main objective is to predict the variable Est Value

# %% [markdown]
# #### Warning

# %% [markdown]
# The goal of this notebook is to provide an easily readable and explainable code that reproduces the main steps
# of training the model. It is not complete: some of the preprocessing done by the DSS visual machine learning is not
# replicated in this notebook. This notebook will not give the same results and model performance as the DSS visual machine
# learning model.

# %% [markdown]
# Let's start with importing the required libs :

# %%
import sys
import dataiku
import numpy as np
import pandas as pd
import sklearn as sk
import dataiku.core.pandasutils as pdu
from dataiku.doctor.preprocessing import PCA
from collections import defaultdict, Counter

# %% [markdown]
# And tune pandas display options:

# %%
pd.set_option('display.width', 3000)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# #### Importing base data

# %% [markdown]
# The first step is to get our machine learning dataset:

# %%
# We apply the preparation that you defined. You should not modify this.
preparation_steps = []
preparation_output_schema = {u'userModified': False, u'columns': [{u'type': u'string', u'name': u'Permit Number'}, {u'type': u'string', u'name': u'Permit Type'}, {u'type': u'string', u'name': u'Permit SubType'}, {u'type': u'string', u'name': u'Permit Status'}, {u'type': u'date', u'name': u'Permit Issue Date'}, {u'type': u'double', u'name': u'Est Value'}, {u'type': u'bigint', u'name': u'State Valuation'}, {u'type': u'string', u'name': u'Contractor'}, {u'type': u'boolean', u'name': u'Corporation'}, {u'type': u'string', u'name': u'Work Desc'}, {u'type': u'string', u'name': u'Work Group'}]}

ml_dataset_handle = dataiku.Dataset('permits_cleaned')
ml_dataset_handle.set_preparation_steps(preparation_steps, preparation_output_schema)
# %time ml_dataset = ml_dataset_handle.get_dataframe(limit = 100000)

print ('Base data has %i rows and %i columns' % (ml_dataset.shape[0], ml_dataset.shape[1]))
# Five first records",
ml_dataset.head(5)
# Out:
# CPU times: user 305 ms, sys: 47.5 ms, total: 353 ms
# Wall time: 4.81 s
# Base data has 36686 rows and 11 columns
#      Permit Number      Permit Type          Permit SubType Permit Status   Permit Issue Date  Est Value  State Valuation                                        Contractor  Corporation Work Desc Work Group
# 0  B 16-110503-ADD  Building Permit  Single Family Dwelling       Finaled 2016-12-30 15:53:40    74500.0            74500  Michael Killa Authentic Construction Company Inc         True  Addition      Other
# 1  B 15-182236-ADD  Building Permit              Commercial       Finaled 2015-12-29 16:04:57   500670.0           500670                                       Rochon Corp         True  Addition      Other
# 2  B 17-209029-ADD  Building Permit  Single Family Dwelling     Inspected 2017-12-28 12:41:29   140000.0           140000                            Cojak Construction LLC         True  Addition      Other
# 3  B 16-100181-ADD  Building Permit  Single Family Dwelling       Finaled 2016-12-28 10:34:50   487000.0           487000                       Mike Fritz M & M Insulation        False  Addition      Other
# 4  B 17-222932-ADD  Building Permit  Single Family Dwelling     Inspected 2017-12-26 13:04:49    25000.0            25000                      Otogawa Anschel Design Build         True  Addition      Other

# %% [markdown]
# #### Initial data management

# %% [markdown]
# The preprocessing aims at making the dataset compatible with modeling.
# At the end of this step, we will have a matrix of float numbers, with no missing values.
# We'll use the features and the preprocessing steps defined in Models.
#
# Let's only keep selected features

# %%
ml_dataset = ml_dataset[[u'Permit Issue Date', u'Est Value', u'Permit SubType', u'Corporation', u'Work Desc', u'Permit Number', u'Permit Status', u'State Valuation']]

# %% [markdown]
# Let's first coerce categorical columns into unicode, numerical features into floats.

# %%
# astype('unicode') does not work as expected

def coerce_to_unicode(x):
    if sys.version_info < (3, 0):
        if isinstance(x, str):
            return unicode(x,'utf-8')
        else:
            return unicode(x)
    else:
        return str(x)


categorical_features = [u'Permit SubType', u'Corporation', u'Work Desc', u'Permit Number', u'Permit Status']
numerical_features = [u'Permit Issue Date', u'State Valuation']
text_features = []
from dataiku.doctor.utils import datetime_to_epoch
for feature in categorical_features:
    ml_dataset[feature] = ml_dataset[feature].apply(coerce_to_unicode)
for feature in text_features:
    ml_dataset[feature] = ml_dataset[feature].apply(coerce_to_unicode)
for feature in numerical_features:
    if ml_dataset[feature].dtype == np.dtype('M8[ns]'):
        ml_dataset[feature] = datetime_to_epoch(ml_dataset[feature])
    else:
        ml_dataset[feature] = ml_dataset[feature].astype('double')

# %% [markdown]
# We renamed the target variable to a column named target

# %%
ml_dataset['__target__'] = ml_dataset['Est Value']
del ml_dataset['Est Value']


# Remove rows for which the target is unknown.
ml_dataset = ml_dataset[~ml_dataset['__target__'].isnull()]

# %% [markdown]
# #### Cross-validation strategy

# %% [markdown]
# The dataset needs to be split into 2 new sets, one that will be used for training the model (train set)
# and another that will be used to test its generalization capability (test set)

# %% [markdown]
# This is a simple cross-validation strategy.

# %%
train, test = pdu.split_train_valid(ml_dataset, prop=0.8)
print ('Train data has %i rows and %i columns' % (train.shape[0], train.shape[1]))
print ('Test data has %i rows and %i columns' % (test.shape[0], test.shape[1]))
# Out:
# Train data has 29348 rows and 8 columns
# Test data has 7338 rows and 8 columns

# %% [markdown]
# #### Features preprocessing

# %% [markdown]
# The first thing to do at the features level is to handle the missing values.
# Let's reuse the settings defined in the model

# %%
drop_rows_when_missing = []
impute_when_missing = [{'impute_with': u'MEAN', 'feature': u'Permit Issue Date'}, {'impute_with': u'MEAN', 'feature': u'State Valuation'}]

# Features for which we drop rows with missing values"
for feature in drop_rows_when_missing:
    train = train[train[feature].notnull()]
    test = test[test[feature].notnull()]
    print ('Dropped missing records in %s' % feature)

# Features for which we impute missing values"
for feature in impute_when_missing:
    if feature['impute_with'] == 'MEAN':
        v = train[feature['feature']].mean()
    elif feature['impute_with'] == 'MEDIAN':
        v = train[feature['feature']].median()
    elif feature['impute_with'] == 'CREATE_CATEGORY':
        v = 'NULL_CATEGORY'
    elif feature['impute_with'] == 'MODE':
        v = train[feature['feature']].value_counts().index[0]
    elif feature['impute_with'] == 'CONSTANT':
        v = feature['value']
    train[feature['feature']] = train[feature['feature']].fillna(v)
    test[feature['feature']] = test[feature['feature']].fillna(v)
    print ('Imputed missing values in feature %s with value %s' % (feature['feature'], coerce_to_unicode(v)))
# Out:
# Imputed missing values in feature Permit Issue Date with value 3693065430.66
# Imputed missing values in feature State Valuation with value 147637.932363
# /Applications/DataScienceStudio.app/Contents/Resources/kit/python.packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# We can now handle the categorical features (still using the settings defined in Models):

# %% [markdown]
# Let's dummy-encode the following features.
# A binary column is created for each of the 100 most frequent values.

# %%
LIMIT_DUMMIES = 100

categorical_to_dummy_encode = [u'Permit SubType', u'Corporation', u'Work Desc', u'Permit Number', u'Permit Status']

# Only keep the top 100 values
def select_dummy_values(train, features):
    dummy_values = {}
    for feature in categorical_to_dummy_encode:
        values = [
            value
            for (value, _) in Counter(train[feature]).most_common(LIMIT_DUMMIES)
        ]
        dummy_values[feature] = values
    return dummy_values

DUMMY_VALUES = select_dummy_values(train, categorical_to_dummy_encode)

def dummy_encode_dataframe(df):
    for (feature, dummy_values) in DUMMY_VALUES.items():
        for dummy_value in dummy_values:
            dummy_name = u'%s_value_%s' % (feature, coerce_to_unicode(dummy_value))
            df[dummy_name] = (df[feature] == dummy_value).astype(float)
        del df[feature]
        print ('Dummy-encoded feature %s' % feature)

dummy_encode_dataframe(train)

dummy_encode_dataframe(test)
# Out:
# Dummy-encoded feature Corporation
# Dummy-encoded feature Permit Status
# Dummy-encoded feature Permit SubType
# Dummy-encoded feature Permit Number
# Dummy-encoded feature Work Desc
# Dummy-encoded feature Corporation
# /Applications/DataScienceStudio.app/Contents/Resources/kit/python.packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Dummy-encoded feature Permit Status
# Dummy-encoded feature Permit SubType
# Dummy-encoded feature Permit Number
# Dummy-encoded feature Work Desc

# %% [markdown]
# Let's rescale numerical features

# %%
rescale_features = {u'Permit Issue Date': u'AVGSTD', u'State Valuation': u'AVGSTD'}
for (feature_name, rescale_method) in rescale_features.items():
    if rescale_method == 'MINMAX':
        _min = train[feature_name].min()
        _max = train[feature_name].max()
        scale = _max - _min
        shift = _min
    else:
        shift = train[feature_name].mean()
        scale = train[feature_name].std()
    if scale == 0.:
        del train[feature_name]
        del test[feature_name]
        print ('Feature %s was dropped because it has no variance' % feature_name)
    else:
        print ('Rescaled %s' % feature_name)
        train[feature_name] = (train[feature_name] - shift).astype(np.float64) / scale
        test[feature_name] = (test[feature_name] - shift).astype(np.float64) / scale
# Out:
# Rescaled Permit Issue Date
# Rescaled State Valuation
# /Applications/DataScienceStudio.app/Contents/Resources/kit/python.packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# #### Modeling

# %% [markdown]
# Before actually creating our model, we need to split the datasets into their features and labels parts:

# %%
train_X = train.drop('__target__', axis=1)
test_X = test.drop('__target__', axis=1)

train_Y = np.array(train['__target__'])
test_Y = np.array(test['__target__'])

# %% [markdown]
# Now we can finally create our model !

# %%
from sklearn.linear_model import RidgeCV
clf = RidgeCV(fit_intercept=True, normalize=True)

# %% [markdown]
# ... And train it

# %%
# %time clf.fit(train_X, train_Y)

# %% [markdown]
# Build up our result dataset

# %%
# %time _predictions = clf.predict(test_X)
predictions = pd.Series(data=_predictions, index=test_X.index, name='predicted_value')

# Build scored dataset
results_test = test_X.join(predictions, how='left')
results_test = results_test.join(test['__target__'], how='left')
results_test = results_test.rename(columns= {'__target__': 'Est Value'})

# %% [markdown]
# #### Results

# %% [markdown]
# You can measure the model's accuracy:

# %%
c =  results_test[['predicted_value', 'Est Value']].corr()
print ('Pearson correlation: %s' % c['predicted_value'][1])

# %% [markdown]
# That's it. It's now up to you to tune your preprocessing, your algo, and your analysis !
